# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=10000,n_features=2,n_clusters_per_class=1,n_redundant=0,n_informative=2)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1], shape=(10000,))

# %%
pd.DataFrame(x)
# Out:
#              0         1
# 0    -1.281533 -0.825773
# 1    -0.742888  0.039724
# 2     0.078804 -1.599147
# 3    -0.491461  2.221101
# 4    -1.571682 -0.283582
# ...        ...       ...
# 9995 -1.479861 -0.079367
# 9996 -1.383456  0.121756
# 9997 -1.444134 -0.891308
# 9998 -0.431277 -1.086943
# 9999 -1.358540 -0.931464
#
# [10000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=44)

# %%
from sklearn.model_selection import GridSearchCV

# %%
pd.DataFrame(x)[0]
# Out:
# 0      -1.281533
# 1      -0.742888
# 2       0.078804
# 3      -0.491461
# 4      -1.571682
#           ...
# 9995   -1.479861
# 9996   -1.383456
# 9997   -1.444134
# 9998   -0.431277
# 9999   -1.358540
# Name: 0, Length: 10000, dtype: float64

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=svc.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      1161
#            1       0.94      0.88      0.90      1339
#
#     accuracy                           0.90      2500
#    macro avg       0.90      0.90      0.90      2500
# weighted avg       0.90      0.90      0.90      2500
#
# [[1080   81]
#  [ 166 1173]]

# %%
from sklearn.svm import SVC
svc1=SVC(verbose=True)
svc1.fit(x_train,y_train)
# Out:
# [LibSVM]
# SVC(verbose=True)

# %%
y_pred_rbf=svc1.predict(x_test)
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      1161
#            1       0.94      0.88      0.90      1339
#
#     accuracy                           0.90      2500
#    macro avg       0.90      0.90      0.90      2500
# weighted avg       0.90      0.90      0.90      2500
#
# [[1080   81]
#  [ 166 1173]]

# %%
from sklearn.model_selection import GridSearchCV

# %%
prarams_grid=
