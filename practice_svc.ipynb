# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=10000,n_features=2,n_clusters_per_class=1,n_redundant=0,n_informative=2,random_state=42)

# %%
y
# Out:
# array([0, 0, 1, ..., 1, 0, 1], shape=(10000,))

# %%
pd.DataFrame(x)
# Out:
#              0         1
# 0     0.204760 -0.357665
# 1    -1.381197  1.390041
# 2     0.564351  0.467320
# 3     1.130436  0.496788
# 4     0.230647 -0.344902
# ...        ...       ...
# 9995  1.111369  0.991471
# 9996  1.235248  1.116814
# 9997  0.717803  0.411917
# 9998 -0.990915  0.766111
# 9999  0.769100  0.957198
#
# [10000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=44)

# %%
from sklearn.model_selection import GridSearchCV

# %%
pd.DataFrame(x)[0]
# Out:
# 0       0.204760
# 1      -1.381197
# 2       0.564351
# 3       1.130436
# 4       0.230647
#           ...
# 9995    1.111369
# 9996    1.235248
# 9997    0.717803
# 9998   -0.990915
# 9999    0.769100
# Name: 0, Length: 10000, dtype: float64

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=svc.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1291
#            1       0.97      0.98      0.98      1209
#
#     accuracy                           0.98      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
# [[1255   36]
#  [  19 1190]]

# %%
from sklearn.svm import SVC
svc1=SVC(verbose=True,kernel='rbf')
svc1.fit(x_train,y_train)
# Out:
# [LibSVM]
# SVC(verbose=True)

# %%
y_pred_rbf=svc1.predict(x_test)
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1291
#            1       0.97      0.98      0.98      1209
#
#     accuracy                           0.98      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
# [[1255   36]
#  [  19 1190]]

# %%
from sklearn.svm import SVC
svc2=SVC(kernel='poly')
svc2.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
y_pred_poly=svc2.predict(x_test)
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1291
#            1       0.97      0.98      0.98      1209
#
#     accuracy                           0.98      2500
#    macro avg       0.98      0.98      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
# [[1255   36]
#  [  19 1190]]

# %%
from sklearn.model_selection import GridSearchCV

# %%
prarams_grid={'C':[0.1,1,10,100,1000],
              'gamma':[1,0.1,0.001,0.0001],
              'kernel':['rbf']
              }
